# %%
#Name = Ishwar Dawalbaje
#COLLAGE = Gov.Poly.Hingoli

# %%
# Assignment Title :  "Explore and clean a Real-World Dataset"

# %%
# 1) Load the Dataset -->

# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\ishwa\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
df = pd.read_csv('netflix_titles.csv')

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.head() #display the first 5 rows
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail() #display the last 5 rows
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
#Save it as a new .csv file .

# %%
df.to_csv('netflix_raw.csv')

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# 2) Basic Exploration -->

# %%
df.shape #shape of dataset (rows and columns)
# Out:
# (8807, 12)

# %%
df.shape[0] #shape of dataset (only rows)
# Out:
# 8807

# %%
df.shape[1] #shape of dataset (only columns)
# Out:
# 12

# %%
df.columns #displaying all columns names in dataset
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df['type'].value_counts()  #Value counts of type column
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
# 3) Data Selection & Slicing -->

# %%
data = df[['title','type','release_year','rating']]

# %%
data
# Out:
#                       title     type  release_year rating
# 0      Dick Johnson Is Dead    Movie          2020  PG-13
# 1             Blood & Water  TV Show          2021  TV-MA
# 2                 Ganglands  TV Show          2021  TV-MA
# 3     Jailbirds New Orleans  TV Show          2021  TV-MA
# 4              Kota Factory  TV Show          2021  TV-MA
# ...                     ...      ...           ...    ...
# 8802                 Zodiac    Movie          2007      R
# 8803            Zombie Dumb  TV Show          2018  TV-Y7
# 8804             Zombieland    Movie          2009      R
# 8805                   Zoom    Movie          2006     PG
# 8806                 Zubaan    Movie          2015  TV-14
#
# [8807 rows x 4 columns]

# %%
#FILTER:
#All TV Shows released after 2018.

# %%
df=df[(df['type']=='TV Show')&(df['release_year'] >2018)]

# %%
df
# Out:
#      show_id     type                                      title  \
# 1         s2  TV Show                              Blood & Water
# 2         s3  TV Show                                  Ganglands
# 3         s4  TV Show                      Jailbirds New Orleans
# 4         s5  TV Show                               Kota Factory
# 5         s6  TV Show                              Midnight Mass
# ...      ...      ...                                        ...
# 8125   s8126  TV Show                                Super Wings
# 8132   s8133  TV Show  Surviving R. Kelly Part II: The Reckoning
# 8173   s8174  TV Show                                  Thackeray
# 8376   s8377  TV Show                       The Kindness Diaries
# 8437   s8438  TV Show                     The Netflix Afterparty
#
#              director                                               cast  \
# 1                 NaN  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
B=df[(df['title']=='Movie') & (df['rating']=='TV-MA') | (df['rating']=='R')]

# %%
B
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
df.loc[0:4] # five rows slicing using loc[]
# Out:
#   show_id     type                  title         director  \
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 3                                                NaN           NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
# ...

# %%
df.iloc[0:5] # five rows slicing using iloc[]
# Out:
#   show_id     type                  title         director  \
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
# 5      s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 3                                                NaN           NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...           NaN
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
# 4) Data Cleaning -->

# %%
#Check for:
#Missing values in all columns.

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        1019
# cast             191
# country          195
# date_added         0
# release_year       0
# rating             0
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
df.duplicated().sum()  #finding duplicate rows
# Out:
# np.int64(0)

# %%
#Fill missing director with "Unknown"

# %%
df['director'].fillna('Unknown')
# Out:
# 1               Unknown
# 2       Julien Leclercq
# 3               Unknown
# 4               Unknown
# 5         Mike Flanagan
#              ...
# 8125            Unknown
# 8132            Unknown
# 8173            Unknown
# 8376            Unknown
# 8437            Unknown
# Name: director, Length: 1148, dtype: object

# %%
df['rating'].dropna
# Out:
# <bound method Series.dropna of 1       TV-MA
# 2       TV-MA
# 3       TV-MA
# 4       TV-MA
# 5       TV-MA
#         ...
# 8125     TV-Y
# 8132    TV-MA
# 8173    TV-MA
# 8376    TV-PG
# 8437    TV-MA
# Name: rating, Length: 1148, dtype: object>

# %%
df.drop_duplicates()
# Out:
#      show_id     type                                      title  \
# 1         s2  TV Show                              Blood & Water
# 2         s3  TV Show                                  Ganglands
# 3         s4  TV Show                      Jailbirds New Orleans
# 4         s5  TV Show                               Kota Factory
# 5         s6  TV Show                              Midnight Mass
# ...      ...      ...                                        ...
# 8125   s8126  TV Show                                Super Wings
# 8132   s8133  TV Show  Surviving R. Kelly Part II: The Reckoning
# 8173   s8174  TV Show                                  Thackeray
# 8376   s8377  TV Show                       The Kindness Diaries
# 8437   s8438  TV Show                     The Netflix Afterparty
#
#              director                                               cast  \
# 1                 NaN  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
#Rename column listed_in to genres

# %%
df['rating'].replace('TV-MA','Mature Audience')
# Out:
# 1       Mature Audience
# 2       Mature Audience
# 3       Mature Audience
# 4       Mature Audience
# 5       Mature Audience
#              ...
# 8125               TV-Y
# 8132    Mature Audience
# 8173    Mature Audience
# 8376              TV-PG
# 8437    Mature Audience
# Name: rating, Length: 1148, dtype: object

# %%
# 5) Export Cleaned Data -->

# %%
df.to_csv('netflix_cleaned.csv')

# %%
dict = {'num' : [11,22,33,44,55]}
df= pd.DataFrame(dict)
df
# Out:
#    num
# 0   11
# 1   22
# 2   33
# 3   44
# 4   55

# %%
avg = df['num'].mean()  #mean() function finds the avarage

# %%
avg
# Out:
# np.float64(33.0)
